# %% [markdown]
# <a href="https://colab.research.google.com/github/itsmevidhyak/Research-Stuff/blob/master/FFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages

import numpy as np
import pandas as pd
import collections
import matplotlib.pyplot as plt
from __future__ import print_function
import seaborn as sns
from datetime import datetime
from dateutil import parser
from pandas_datareader import data
from mpl_toolkits.mplot3d import Axes3D
from scipy.fftpack import fft

# %%
# Dataset sample

dat = data.DataReader('GOOG', 'stooq')
plt.plot(dat['Close'])
plt.show

time_series_data = dat['Close']

# %%
time_series_data.shape
# Out:
# (1466,)

# %%
# FFT

def get_fft_values(y_values, T, N, f_s):
    f_values = np.linspace(0.0, 1.0/(2.0*T), N//2)
    fft_values_ = fft(y_values)
    fft_values = 2.0/N * np.abs(fft_values_[0:N//2])
    return f_values, fft_values

t_n = 1
N = 1466
T = t_n / N
f_s = 1/T

f_values, fft_values = get_fft_values(time_series_data, T, N, f_s)
 
plt.plot(f_values, fft_values, linestyle='-', color='blue')
plt.xlabel('Frequency [Hz]', fontsize=16)
plt.ylabel('Amplitude', fontsize=16)
plt.title("Frequency domain of the signal", fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/fft/_pocketfft/helper.py:95: FutureWarning: Series.flags is deprecated and will be removed in a future version
#   return np.array(x, copy=not x.flags['ALIGNED'])
